# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\LENOVO\\OneDrive\\Documents\\Decode Lab Internship\\first practical\\employee_data_dirty_1500.csv')

# %% [markdown]
# # Before cleaning

# %%
df.info(),df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   1500 non-null   int64
#  1   Name         1500 non-null   object
#  2   Department   1500 non-null   object
#  3   Age          1447 non-null   float64
#  4   Salary       1500 non-null   int64
#  5   City         1500 non-null   object
#  6   JoiningDate  1500 non-null   object
#  7   Email        1500 non-null   object
#  8   Phone        1500 non-null   int64
#  9   Performance  1500 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 117.3+ KB
# (None,
#     EmployeeID                Name Department   Age  Salary             City  \
#  0        1454  Randall Richardson      Sales  27.0   63251   South Chadport
#  1        1638   Valerie Garcia MD    Finance   NaN   84957        Lake John
# ...

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df.isnull().sum()
# Out:
# EmployeeID     0
# Name           0
# Department     0
# Age            0
# Salary         0
# City           0
# JoiningDate    0
# Email          0
# Phone          0
# Performance    0
# dtype: int64

# %%
print(df["EmployeeID"].duplicated().sum())
df=df.drop_duplicates(subset=["EmployeeID"], keep="first")
print(df["EmployeeID"].duplicated().sum())
df.shape
# Out:
# 671
# 0
# (829, 10)

# %%
df['Phone']=df['Phone'].astype(str)
df['EmployeeID']=df['EmployeeID'].astype(str)
df['Age']=df['Age'].astype(int)

# %%
df['JoiningDate']=pd.to_datetime(df['JoiningDate'], errors='coerce',format='mixed')
df['JoiningDate'].isna().sum()
# Out:
# np.int64(0)

# %%
(df["Phone"].str.len() != 10).sum()
# Out:
# np.int64(73)

# %%
df.loc[df["Phone"].str.len() != 10, "Phone"] = "Invalid Number"
df["Name"] = df["Name"].str.strip().str.title()

# %%
invalid_email = ~df["Email"].str.contains(
    r"^[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}$",
    regex=True
)

df.loc[invalid_email, "Email"] = "Invalid Email"
print((df["Email"] == "Invalid Email").sum())
# Out:
# 41

# %% [markdown]
# # After cleaning

# %%
df.info(),df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 829 entries, 0 to 1495
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   829 non-null    object
#  1   Name         829 non-null    object
#  2   Department   829 non-null    object
#  3   Age          829 non-null    int64
#  4   Salary       829 non-null    int64
#  5   City         829 non-null    object
#  6   JoiningDate  829 non-null    datetime64[ns]
#  7   Email        829 non-null    object
#  8   Phone        829 non-null    object
#  9   Performance  829 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(7)
# memory usage: 71.2+ KB
# (None,
#    EmployeeID                Name Department  Age  Salary             City  \
#  0       1454  Randall Richardson      Sales   27   63251   South Chadport
#  1       1638   Valerie Garcia Md    Finance   40   84957        Lake John
# ...

# %%
df.to_csv('C:\\Users\\LENOVO\\OneDrive\\Documents\\Decode Lab Internship\\employee_data_cleaned.csv', index=False)
