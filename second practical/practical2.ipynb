# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

# %%
df = pd.read_csv("employee_data_cleaned.csv")

df.head()
# Out:
#    EmployeeID                Name Department  Age  Salary             City  \
# 0        1454  Randall Richardson      Sales   27   63251   South Chadport
# 1        1638   Valerie Garcia Md    Finance   40   84957        Lake John
# 2        2134        Megan Osborn         IT   27  114707  New Rachelmouth
# 3        1452      Sharon Bonilla         IT   55   78545    Lake Tinafurt
# 4        1867       Sandra Graham         HR   44   96729   North Veronica
#
#   JoiningDate                   Email           Phone Performance
# 0  2019-11-06  nelsonryan@griffin.com      9745717285     Average
# 1  2019-08-19   charles55@hotmail.com      3291973649     Average
# 2  2020-07-06   hurleyjason@gmail.com  Invalid Number        Good
# 3  2021-06-01   valeriecain@yahoo.com      6002709228     Average
# 4  2020-07-17   christine46@gmail.com      6802411051        Poor

# %%
print("Dataset Shape:", df.shape)

df.info()
# Out:
# Dataset Shape: (829, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829 entries, 0 to 828
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   829 non-null    int64
#  1   Name         829 non-null    object
#  2   Department   829 non-null    object
#  3   Age          829 non-null    int64
#  4   Salary       829 non-null    int64
#  5   City         829 non-null    object
#  6   JoiningDate  829 non-null    object
#  7   Email        829 non-null    object
#  8   Phone        829 non-null    object
#  9   Performance  829 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 64.9+ KB

# %%
df.describe()
# Out:
#         EmployeeID         Age         Salary
# count   829.000000  829.000000     829.000000
# mean   1606.096502   40.231604   73271.729795
# std     348.275049   11.407660   27264.872597
# min    1000.000000   21.000000   25001.000000
# 25%    1301.000000   30.000000   49792.000000
# 50%    1611.000000   40.000000   74533.000000
# 75%    1907.000000   50.000000   96420.000000
# max    2200.000000   60.000000  119974.000000

# %%
df.isnull().sum()
# Out:
# EmployeeID     0
# Name           0
# Department     0
# Age            0
# Salary         0
# City           0
# JoiningDate    0
# Email          0
# Phone          0
# Performance    0
# dtype: int64

# %%
print("Average Age:", round(df["Age"].mean(),2))
print("Median Age:", df["Age"].median())

print("Average Salary:", round(df["Salary"].mean(),2))
print("Median Salary:", df["Salary"].median())

print("Highest Salary:", df["Salary"].max())
print("Lowest Salary:", df["Salary"].min())
# Out:
# Average Age: 40.23
# Median Age: 40.0
# Average Salary: 73271.73
# Median Salary: 74533.0
# Highest Salary: 119974
# Lowest Salary: 25001

# %%
department_count = df["Department"].value_counts()

department_count
# Out:
# Department
# IT            156
# HR            152
# Finance       144
# Sales         133
# Marketing     127
# Operations    117
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="Department",
    order=df["Department"].value_counts().index
)

plt.title("Employees by Department")
plt.xticks(rotation=45)

plt.show()

# %%
performance_count = df["Performance"].value_counts()

performance_count
# Out:
# Performance
# Average      214
# Good         213
# Excellent    208
# Poor         194
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))

sns.countplot(
    data=df,
    x="Performance",
    order=df["Performance"].value_counts().index
)

plt.title("Performance Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    df["Salary"],
    bins=20,
    kde=True
)

plt.title("Salary Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    df["Age"],
    bins=15,
    kde=True
)

plt.title("Age Distribution")

plt.show()

# %%
plt.figure(figsize=(8,4))

sns.boxplot(
    x=df["Salary"]
)

plt.title("Salary Outliers")

plt.show()

# %%
dept_salary = (
    df.groupby("Department")["Salary"]
    .mean()
    .sort_values(ascending=False)
)

dept_salary
# Out:
# Department
# HR            75693.532895
# Finance       75688.291667
# Operations    74431.247863
# Sales         72553.842105
# Marketing     71999.322835
# IT            69459.628205
# Name: Salary, dtype: float64

# %%
plt.figure(figsize=(8,5))

dept_salary.plot(kind="bar")

plt.title("Average Salary by Department")
plt.ylabel("Salary")

plt.show()

# %%
correlation = df[["Age","Salary"]].corr()

correlation
# Out:
#              Age    Salary
# Age     1.000000  0.009079
# Salary  0.009079  1.000000

# %%
plt.figure(figsize=(5,4))

sns.heatmap(
    correlation,
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Heatmap")

plt.show()

# %%
df["City"].value_counts().head(10)
# Out:
# City
# East James       4
# West David       3
# Markview         2
# North Richard    2
# South Amber      2
# Schroederton     2
# West James       2
# Lake Emily       2
# West Michael     2
# Lake Patricia    2
# Name: count, dtype: int64

# %%
print("""
1. The dataset contains 829 employee records.

2. Average employee age is approximately 40 years.

3. Average salary is approximately 73,272.

4. IT department has the highest number of employees.

5. Operations department has the lowest number of employees.

6. Most employees have an Average performance rating.

7. HR department has the highest average salary.

8. Salary distribution shows some high-value outliers.

9. No missing values are present in the cleaned dataset.

10. The dataset is ready for further analysis and visualization.
""")
# Out:
# 1. The dataset contains 829 employee records.
#
# 2. Average employee age is approximately 40 years.
#
# 3. Average salary is approximately 73,272.
#
# 4. IT department has the highest number of employees.
#
# 5. Operations department has the lowest number of employees.
#
# 6. Most employees have an Average performance rating.
#
# 7. HR department has the highest average salary.
#
# 8. Salary distribution shows some high-value outliers.
#
# 9. No missing values are present in the cleaned dataset.
#
# 10. The dataset is ready for further analysis and visualization.
